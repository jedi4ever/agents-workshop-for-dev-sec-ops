# %% [markdown]
# # Lesson 4 - Multiple Agents using CrewAI

# %%
# We first install the packages
# %pip install crewai langchain langchain-openai --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# We install our environment variables helper library
# %pip install python-dotenv --quiet
import dotenv
dotenv.load_dotenv()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# True

# %%
# We load our helper callback to see what goes over the wire
from _callbacks import PrettyPrintCallbackHandler
callback = PrettyPrintCallbackHandler()

# %%
# We load the llm mode using our helper and based onthe settings
import _models
import _settings
llm=_models.get_llm(_settings.MODEL_NAME, callbacks=[callback])

# %%
# We load our challenge from the settings
import _settings
challenge_prompt=_settings.CHALLENGE_PROMPT

# %%
# %pycat _agents.py
# Out:
# from crewai import Agent
#
# def get_agent_by_name(name, llm):
#     if name == 'senior developer':
#         print("Creating senior developer")
#         return senior_developer(llm)
#     elif name == 'senior devops':
#         print("Creating senior devops")
#         return senior_devops(llm)
#     else:
#         return None
#
# def senior_developer(llm):
#     return Agent(
#         role='Senior Developer',
#         goal='Develop code that is high quality, scalable, and maintainable.',
#         backstory="""You are a senior developer with 10 years of experience.
#         You have worked on a variety of projects and have a deep understanding of software development best practices.
#         You are passionate about writing clean, efficient code and am always looking for ways to improve my skills.
#         """,
#         verbose=True,
#         # You can pass an optional llm attribute specifying what model you wanna use.
#         # llm=ChatOpenAI(model_name="gpt-3.5", temperature=0.7),
#         llm=llm
#     )
#
# def senior_devops(llm):
#     return Agent(
#         role='Senior DevOps Engineer',
#         goal='Make sure the code works repeatably and is idempotent.',
#         backstory="""You are a senior Devops Engineer with 10 years of experience.
#         You write a lot of bash scripts as you live in the terminal all day.`
#         """,
#         verbose=True,
#         llm=llm
#         # You can pass an optional llm attribute specifying what model you wanna use.
#         # llm=ChatOpenAI(model_name="gpt-3.5", temperature=0.7),
#     )

# %%
import _agents
developer= _agents.get_agent_by_name("senior developer",llm)
#print(developer)

# %%
import _settings
print(_settings.CHALLENGE_PROMPT)

from crewai import Agent, Task, Crew

# Create tasks for your agents
task1 = Task(
  description=challenge_prompt,
  expected_output="A script shown as markdown code block",
  agent=developer,
  llm=llm
)
# Out:
# Write me a shell script to list the files in the current directory.
# Output the script as markdown code block

# %%
# Instantiate your crew with a sequential process
crew = Crew(
  agents=[developer],
  tasks=[task1],
  verbose=2, # You can set it to 1 or 2 to different logging levels
)

# Get your crew to work!
result = crew.kickoff()

print("######################")
print(result)
# Out:
#  [DEBUG]: == Working Agent: Senior Developer
#  [INFO]: == Starting Task: Write me a shell script to list the files in the current directory.
# Output the script as markdown code block
#
#
# > Entering new CrewAgentExecutor chain...
# [chat_model][start] - prompts : You are Senior Developer. You are a senior developer with 10 years of experience.
#         You have worked on a variety of projects and have a deep understanding of software development best practices.
#         You are passionate about writing clean, efficient code and am always looking for ways to improve my skills.
#
# Your personal goal is: Develop code that is high quality, scalable, and maintainable.To give my best complete final answer to the task use the exact following format:
#
# Thought: I now can give a great answer
# Final Answer: my best complete final answer to the task.
# Your final answer must be the great and the most complete as possible, it must be outcome described.
#
# I MUST use these formats, my job depends on it!
# Current Task: Write me a shell script to list the files in the current directory.
# Output the script as markdown code block
#
# This is the expect criteria for your final answer: A script shown as markdown code block
#  you MUST return the actual complete content as the final answer, not a summary.
#
# Begin! This is VERY important to you, use the tools available and give your best Final Answer, your job depends on it!
#
# Thought:
#
# [llm][new_token]
# [llm][new_token] I
# [llm][new_token]  can
# [llm][new_token]  write
# [llm][new_token]  a
# [llm][new_token]  simple
# [llm][new_token]  shell
# [llm][new_token]  script
# [llm][new_token]  that
# [llm][new_token]  lists
# [llm][new_token]  all
# [llm][new_token]  the
# [llm][new_token]  files
# [llm][new_token]  in
# [llm][new_token]  the
# [llm][new_token]  current
# [llm][new_token]  directory
# [llm][new_token] .
# [llm][new_token]  I
# [llm][new_token]  will
# [llm][new_token]  use
# [llm][new_token]  the
# [llm][new_token]  `
# [llm][new_token] ls
# [llm][new_token] `
# [llm][new_token]  command
# [llm][new_token] ,
# [llm][new_token]  which
# [llm][new_token]  is
# [llm][new_token]  a
# [llm][new_token]  standard
# [llm][new_token]  command
# [llm][new_token]  to
# [llm][new_token]  list
# [llm][new_token]  files
# [llm][new_token]  in
# [llm][new_token]  Unix
# [llm][new_token]  and
# [llm][new_token]  Unix
# [llm][new_token] -like
# [llm][new_token]  operating
# [llm][new_token]  systems
# [llm][new_token] .
# [llm][new_token]  I
# [llm][new_token]  will
# [llm][new_token]  output
# [llm][new_token]  the
# [llm][new_token]  script
# [llm][new_token]  as
# [llm][new_token]  a
# [llm][new_token]  markdown
# [llm][new_token]  code
# [llm][new_token]  block
# [llm][new_token]  as
# [llm][new_token]  requested
# [llm][new_token] .
#
#
# [llm][new_token] Final
# [llm][new_token]  Answer
# [llm][new_token] :
#
#
# [llm][new_token] Here
# [llm][new_token]  is
# [llm][new_token]  the
# [llm][new_token]  shell
# [llm][new_token]  script
# [llm][new_token]  as
# [llm][new_token]  a
# [llm][new_token]  markdown
# [llm][new_token]  code
# [llm][new_token]  block
# [llm][new_token] :
#
#
# [llm][new_token] ```
# [llm][new_token] bash
# [llm][new_token]
#
# [llm][new_token] #!/
# [llm][new_token] bin
# [llm][new_token] /bash
# [llm][new_token]
#
# [llm][new_token] #
# [llm][new_token]  This
# [llm][new_token]  script
# [llm][new_token]  will
# [llm][new_token]  list
# [llm][new_token]  all
# [llm][new_token]  the
# [llm][new_token]  files
# [llm][new_token]  in
# [llm][new_token]  the
# [llm][new_token]  current
# [llm][new_token]  directory
# [llm][new_token]
#
# [llm][new_token] ls
# [llm][new_token]
#
# [llm][new_token] ``
# [llm][new_token] `
#
#
# [llm][new_token] To
# [llm][new_token]  run
# [llm][new_token]  this
# [llm][new_token]  script
# [llm][new_token] ,
# [llm][new_token]  save
# [llm][new_token]  it
# [llm][new_token]  to
# [llm][new_token]  a
# [llm][new_token]  file
# [llm][new_token] ,
# [llm][new_token]  give
# [llm][new_token]  it
# [llm][new_token]  execute
# [llm][new_token]  permissions
# [llm][new_token]  using
# [llm][new_token]  `
# [llm][new_token] chmod
# [llm][new_token]  +
# [llm][new_token] x
# [llm][new_token]  filename
# [llm][new_token] `,
# [llm][new_token]  and
# [llm][new_token]  then
# [llm][new_token]  run
# [llm][new_token]  it
# [llm][new_token]  with
# [llm][new_token]  `
# [llm][new_token] ./
# [llm][new_token] filename
# [llm][new_token] `.
# [llm][new_token]  It
# [llm][new_token]  will
# [llm][new_token]  list
# [llm][new_token]  all
# [llm][new_token]  the
# [llm][new_token]  files
# [llm][new_token]  in
# [llm][new_token]  the
# [llm][new_token]  directory
# [llm][new_token]  where
# [llm][new_token]  it
# [llm][new_token]  is
# [llm][new_token]  run
# [llm][new_token] .
# [llm][new_token]
#
# =============
# [llm][end] - generation I can write a simple shell script that lists all the files in the current directory. I will use the `ls` command, which is a standard command to list files in Unix and Unix-like operating systems. I will output the script as a markdown code block as requested.
#
# Final Answer:
#
# Here is the shell script as a markdown code block:
#
# ```bash
# #!/bin/bash
# # This script will list all the files in the current directory
# ls
# ```
#
# To run this script, save it to a file, give it execute permissions using `chmod +x filename`, and then run it with `./filename`. It will list all the files in the directory where it is run.
# I can write a simple shell script that lists all the files in the current directory. I will use the `ls` command, which is a standard command to list files in Unix and Unix-like operating systems. I will output the script as a markdown code block as requested.
#
# Final Answer:
#
# Here is the shell script as a markdown code block:
#
# ```bash
# #!/bin/bash
# # This script will list all the files in the current directory
# ls
# ```
#
# To run this script, save it to a file, give it execute permissions using `chmod +x filename`, and then run it with `./filename`. It will list all the files in the directory where it is run.
#
# > Finished chain.
#  [DEBUG]: == [Senior Developer] Task output: Here is the shell script as a markdown code block:
#
# ```bash
# #!/bin/bash
# # This script will list all the files in the current directory
# ls
# ```
#
# To run this script, save it to a file, give it execute permissions using `chmod +x filename`, and then run it with `./filename`. It will list all the files in the directory where it is run.
#
#
# ######################
# Here is the shell script as a markdown code block:
#
# ```bash
# #!/bin/bash
# # This script will list all the files in the current directory
# ls
# ```
#
# To run this script, save it to a file, give it execute permissions using `chmod +x filename`, and then run it with `./filename`. It will list all the files in the directory where it is run.
